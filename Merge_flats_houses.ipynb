# %%
import numpy as np
import pandas as pd

# %%
flats = pd.read_csv('flats_cleaned.csv')
houses = pd.read_csv('house_cleaned.csv')

# %%
df = pd.concat([flats, houses],ignore_index=True)

# %%
df = df.sample(df.shape[0],ignore_index=True)

# %%
df.head()
# Out:
#                                     property_name property_type  \
# 0                 4 BHK Flat in Sector 85 Gurgaon          flat
# 1  4 Bedroom House for sale in Sector 70A Gurgaon         house
# 2                4 BHK Flat in Sector 104 Gurgaon          flat
# 3                 3 BHK Flat in Sector 85 Gurgaon          flat
# 4                2 BHK Flat in Sector 107 Gurgaon          flat
#
#                    society  price  price_per_sqft    area  \
# 0              ss the leaf   2.20          5641.0  3900.0
# 1         bptp visionnaire   4.70         18008.0  2610.0
# 2              ats triumph   2.60          8813.0  2950.0
# 3              ss the leaf   1.99          8659.0  2298.0
# 4  signature global solera   0.40          6644.0   602.0
#
#                                         areaWithType  bedRoom  bathroom  \
# 0  Super Built up area 3950(366.97 sq.m.)Built Up...        4         6
# 1                        Plot area 290(242.48 sq.m.)        4         4
# 2  Super Built up area 3150(292.64 sq.m.)Carpet a...        4         4
# 3  Super Built up area 2408(223.71 sq.m.)Built Up...        3         4
# 4  Super Built up area 602(55.93 sq.m.)Carpet are...        2         2
#
#   balcony additionalRoom                                           address  \
# 0       3   servant room     Vvvvvvvv, Sector 85 Gurgaon, Gurgaon, Haryana
# 1      3+         others      B- 186, Sector 70A Gurgaon, Gurgaon, Haryana
# 2      3+   servant room        16th, Sector 104 Gurgaon, Gurgaon, Haryana
# 3      3+   servant room         B265, Sector 85 Gurgaon, Gurgaon, Haryana
# 4       1  not available  Sector 107, Sector 107 Gurgaon, Gurgaon, Haryana
#
#    floorNum      facing    agePossession  \
# 0      10.0  North-West  1 to 5 Year Old
# 1       3.0  North-East  0 to 1 Year Old
# 2      16.0        East  1 to 5 Year Old
# 3      17.0        East  1 to 5 Year Old
# 4       7.0         NaN  1 to 5 Year Old
#
#                                      nearbyLocations  \
# 0  ['Sapphire 83 Mall', 'Dwarka Expressway', 'Cen...
# 1  ['Good Earth City Center 2', 'Kunskapsskolan I...
# 2  ['IFFCO Chowk Metro Station', 'The Esplanade M...
# 3  ['Sapphire 83 Mall', 'Dwarka Expressway', 'Cen...
# 4  ['Gurgaon Dreamz Mall', 'Dwarka Expressway', "...
#
#                                          description  \
# 0  Check out this 4 bhk apartment for sale in ss ...
# 1  Planning to buy an individual house in gurgaon...
# 2  This 4 bhk flat is located in ats triumph, whi...
# 3  This 3 bhk flat is located in ss the leaf, whi...
# 4  Best in class property available at sector 107...
#
#                                       furnishDetails  \
# 0  ['5 Fan', '6 Light', '4 AC', 'No Bed', 'No Chi...
# 1  ['1 Fan', '1 Geyser', '1 Light', '1 Chimney', ...
# 2  ['6 Fan', '1 Exhaust Fan', '16 Light', '6 AC',...
# 3  ['4 Fan', '1 Exhaust Fan', '10 Light', '2 AC',...
# 4  ['3 Fan', '1 Exhaust Fan', '5 Light', '1 Modul...
#
#                                             features  \
# 0  ['Centrally Air Conditioned', 'Water purifier'...
# 1  ['Feng Shui / Vaastu Compliant', 'Private Gard...
# 2  ['Water purifier', 'Security / Fire Alarm', 'F...
# 3  ['Centrally Air Conditioned', 'Water purifier'...
# 4                                                NaN
#
#                                               rating
# 0  ['Green Area4.5 out of 5', 'Construction4.5 ou...
# 1  ['Environment5 out of 5', 'Safety4 out of 5', ...
# 2  ['Green Area4 out of 5', 'Construction5 out of...
# 3  ['Green Area4.5 out of 5', 'Construction4.5 ou...
# 4  ['Green Area4.5 out of 5', 'Construction4.5 ou...

# %%
df.to_csv('gurgaon_properties.csv',index=False)
